# %%
import matplotlib as plt
import yfinance as yf
from datetime import date
import datetime 

today = date.today()
yesterday = today - datetime.timedelta(days=1)

figsize = (14, 10)
# Out:
# ciao

# %%
# %%time
import yfinance as yf

tsla_df = yf.download('TSLA', 
                      start='2020-04-16', 
                      end = '2020-04-17',
                      #end=today, 
                      interval='1m',
                      progress=False)
tsla_df = tsla_df.iloc[:-1]
open_v = tsla_df[['Open']]
# Out:
# Wall time: 381 ms

# %%
open_v.plot(figsize=figsize)

# %%
open_v

# %%
import pandas as pd
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = table[0]
df.to_csv('S&P500-Info.csv')
df.to_csv("S&P500-Symbols.csv", columns=['Symbol'])

# %%
import yfinance as yf

msft = yf.Ticker("NFLX")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="max")

# show actions (dividends, splits)
a = msft.get_cashflow(proxy="PROXY_SERVER")

# %%
a
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#import packages
import requests
import json
# Get income statement using request package and convert to json
stock = 'NFLX'   
income_statement =  requests.get(f"https://financialmodelingprep.com/api/v3/company/rating/{stock}")
income_statement = income_statement.json()
symbols = requests.get('https://financialmodelingprep.com/api/v3/company/profile/AAPL')
symbols = symbols.json()

# %%
sample = symbols['symbolsList'][:400]

# %%
for j, stock in enumerate(symbols['symbolsList']):
    income_statement =  requests.get(f"https://financialmodelingprep.com/api/v3/company/rating/{stock}")
    if j%10==0:
        print(j)
# Out:
# 0
# 10
# 20
# 30
# 40
# --------------------------------------------------------
# KeyboardInterrupt      Traceback (most recent call last)
# <ipython-input-38-2c197390c0d4> in <module>
#       1 for j, stock in enumerate(symbols['symbolsList']):
# ----> 2     income_statement =  requests.get(f"https://financialmodelingprep.com/api/v3/company/rating/{stock}")
#       3     if j%10==0:
#       4         print(j)
#
# c:\users\giacomo\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\giacomo\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ...
